# %%
#hashing is fast searching

# %%
# for binary search array should be sorted  o(logn)
# break the arrary and check which side the element is and select the array and again repeat the process

# %%
# hashing give searching in constant time o(1)
